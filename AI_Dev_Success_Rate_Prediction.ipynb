# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings as wr
wr.filterwarnings("ignore")
plt.style.use("default")
sns.set(font_scale=1.1)

# %% [markdown]
# ## Load the Dataset

# %%
df = pd.read_csv(r"C:\Users\Din islam\Downloads\ai_dev_task_success_rate_prediction\AI_Developer_Performance_Extended_1000.csv")
df.head()
# Out:
#    Hours_Coding  Lines_of_Code  Bugs_Found  Bugs_Fixed  AI_Usage_Hours  \
# 0             7            416           9           7               6
# 1             4            269          16          13               5
# 2            11            439           3           0               2
# 3             8            472          15           9               4
# 4             5            265          19          16               5
#
#    Sleep_Hours  Cognitive_Load  Task_Success_Rate  Coffee_Intake  \
# 0          5.9              92                 34              7
# 1          5.1              85                 36              2
# 2          6.2              38                 79              2
# 3          4.2              26                 94              5
# 4          8.1              82                 33              6
#
#    Stress_Level  Task_Duration_Hours  Commits  Errors
# 0            99                 10.5       20       3
# ...

# %% [markdown]
# #### Basic info about the dataset

# %%
# to know the number of columns and rows in the dataset
df.shape
# Out:
# (1000, 13)

# %%
# To know the datatype of each column and if there are any null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Hours_Coding         1000 non-null   int64
#  1   Lines_of_Code        1000 non-null   int64
#  2   Bugs_Found           1000 non-null   int64
#  3   Bugs_Fixed           1000 non-null   int64
#  4   AI_Usage_Hours       1000 non-null   int64
#  5   Sleep_Hours          1000 non-null   float64
#  6   Cognitive_Load       1000 non-null   int64
#  7   Task_Success_Rate    1000 non-null   int64
#  8   Coffee_Intake        1000 non-null   int64
#  9   Stress_Level         1000 non-null   int64
#  10  Task_Duration_Hours  1000 non-null   float64
#  11  Commits              1000 non-null   int64
#  12  Errors               1000 non-null   int64
# dtypes: float64(2), int64(11)
# memory usage: 101.7 KB

# %%
# In this dataset, there are 1000 rows and 13 columns. 
# All the columns are of numerical datatype and there are no null values in any column.

# %% [markdown]
# ### Quick descriptive statistics for numerical columns

# %%
df.describe().T
# Out:
#                       count      mean         std   min    25%     50%    75%  \
# Hours_Coding         1000.0    5.8400    3.158540   1.0    3.0    6.00    9.0
# Lines_of_Code        1000.0  356.2340  188.155350  26.0  209.5  332.00  480.5
# Bugs_Found           1000.0    9.8760    5.796052   0.0    5.0   10.00   15.0
# Bugs_Fixed           1000.0    7.1530    5.468226   0.0    2.0    7.00   12.0
# AI_Usage_Hours       1000.0    2.9610    2.021278   0.0    1.0    3.00    5.0
# Sleep_Hours          1000.0    6.4658    1.439529   4.0    5.2    6.40    7.7
# Cognitive_Load       1000.0   56.9330   21.767506  20.0   38.0   57.00   76.0
# Task_Success_Rate    1000.0   56.5780   20.814879  30.0   37.0   55.50   74.0
# Coffee_Intake        1000.0    3.3680    2.342234   0.0    1.0    3.00    5.0
# Stress_Level         1000.0   66.4100   21.865452  30.0   48.0   66.00   86.0
# Task_Duration_Hours  1000.0    8.7001    5.992891   0.5    4.0    7.45   12.0
# ...
